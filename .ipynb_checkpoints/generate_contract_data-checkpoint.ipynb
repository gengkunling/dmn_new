# %%
import pandas as pd
import os
import spacy
# Install: pip install spacy && python -m spacy download en
#import spacy

# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load('en')



#print os.getcwd()
f_company = "data/contract_data/fortune1000.xls"
parsed = pd.read_excel(f_company, skiprows=5, dtype = str)

# %%
#print parsed['Company']
company_names = parsed['Company']
company_streets = parsed['Address']
company_cities = parsed['City']
company_states = parsed['State']
company_zips = parsed['Zipcode']

# %%
N_company = len(company_names)

# %%
print N_company
# Out:
# 996

# %%
contract1 =  "THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE \
( Effective Date ) between CONTRACTOR_NAME ( Contractor ), CONTRACTOR_ADDR, and CONTRACTEE_NAME ( Operator ).  \
Contractor and Operator are also referred to as  party  and collectively as the  parties .  \
Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, \
the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: \
Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017."

contract2 =  "THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE \
( Effective Date ) between CONTRACTOR_NAME, CONTRACTOR_ADDR, ( Contractor ) and CONTRACTEE_NAME ( Operator ).  \
Contractor and Operator are also referred to as  party  and collectively as the  parties .  \
Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, \
the receipt and sufficiency of which are hereby acknowledged."

contract3 = "THIS AGREEMENT made effective this EFFECTIVE_DATE by and between CONTRACTEE_NAME hereinafter called \
\"Company\" and CONTRACTOR_NAME, CONTRACTOR_ADDR, hereinafter called \"Contractor,\" whereby, in \
consideration of the covenants and provisions hereinafter provided, this Agreement shall control \
and govern all work performed or \
to be performed by Contractor for Company under verbal or written work orders, purchase orders, \
delivery tickets, voices or other verbal or written agreements between the Parties, relating to \
work to be done by Contractor for Company, and upersede any \
such previous agreements from date hereof until specifically cancelled in writing by either Party, \
anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company \
to order work from Contractor, nor obligate Contractor to accept orders for work"



contract4 = "This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between \
The CONTRACTOR_NAME, a Virginia corporation (Consultant), and the CONTRACTEE_NAME, a municipal corporation and \
home rule unit of local government existing under the Constitution of the State of Illinois, acting through its \
Office of Emergency Management and Communications (City), at Chicago, Illinois."

contract5= "This Master Task Order Contract is entered into as of the EFFECTIVE_DATE \
(Effective Date) by and between CONTRACTOR_NAME, Inc., (Consultant), CONTRACTOR_ADDR, and the CONTRACTEE_NAME, CONTRACTEE_ADDR\
 and home rule unit of local government existing under the Constitution of \
the State of Illinois, acting through its Chicago Department of Public Health (City), at Chicago, Illinois."


    
contract6 =  "THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE \
( Effective Date ) between CONTRACTOR_NAME ( Contractor ), CONTRACTOR_ADDR, and \
CONTRACTEE_NAME ( Operator ), CONTRACTEE_ADDR  \
Contractor and Operator are also referred to as  party  and collectively as the  parties . \
Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, \
the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: \
Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017."


contract7 = "This Services Agreement (the Agreement) sets forth terms under that The CONTRACTOR_NAME (Company), CONTRACTOR_ADDR \
shall provide services to \
the CONTRACTEE_NAME (the Client). This Agreement is effective as \
of EFFECTIVE_DATE (Effective Date)."


contract8 = "THIS AGREEMENT (Agreement), which comprises the full and complete agreement of \
the Parties hereto and supersedes all previous agreements between the Parties relating to the \
subject matter hereof, is entered into the EFFECTIVE_DATE, \
by and between CONTRACTEE_NAME, CONTRACTEE_ADDR, \
for itself and its wholly owned subsidiaries (Company), \
and CONTRACTOR_NAME, CONTRACTOR_ADDR, (Contractor). \
Company and Contractor are sometimes referred to hereinafter individually as a \
Party or collectively as the Parties."


contract9 = "This contract serves as the Master Services Agreement \
(Agreement) under which orders may be issued for professional services to \
be performed by the division of CONTRACTOR_NAME listed in the \
Addresses and Points of Contact section of this Agreement. This Agreement  \
is entered into by CONTRACTOR_NAME, CONTRACTOR_ADDR, \
and CONTRACTEE_NAME, CONTRACTEE_ADDR,  and is effective as of \
date signed. This agreement is effective from EFFECTIVE_DATE. \
For the purposes of this agreement, CONTRACTOR_NAME and the Customer may be referred to as such or \
as the Parties to this agreement."


contract10 = "This contract is entered into on this EFFECTIVE_DATE, by and between CONTRACTOR_NAME, a \
municipal corporation of the State of California and The CONTRACTEE_NAME, CONTRACTEE_ADDR. \
This contract consists of \
the following documents:"

contract_templates = [contract1, contract2, contract3, contract4, contract5, contract6, contract7, contract8, contract9, contract10]
N_template = len(contract_templates)

# %%
from datetime import datetime
import random

def random_day():
    year = random.choice(range(1950, 2018))
    month = random.choice(range(1, 13))
    if month == 2:
        if year % 4 == 0:
            day = random.choice(range(1, 30))
        else:
            day = random.choice(range(1, 29))
    elif month in [1, 3, 5, 7, 8, 10, 12]:
        day = random.choice(range(1, 32))
    else:
        day = random.choice(range(1, 31))
    random_date = datetime(year, month, day)
    return random_date

def random_day_str():
    random_date = random_day()
    
    format_choice = random.choice(["%B %d, %Y","%b %d, %Y", "%m %d, %Y", "%B %d, %Y", "%B %d, %y", "%m %d, %y","%D", "%F"])
    random_date_str = random_date.strftime(format_choice)
    return  random_date_str

# %%
def qa_gen(contractor_name, contractee_name, contractor_addr, contractee_addr, effective_date):
    answers = [contractor_name, contractee_name, contractor_addr, contractee_addr, effective_date]
    types = ["contractor name", "contractee name", "contractor address", "contractee address", "effective date"]
    ques_ans_list = []
    for i, ans in enumerate(answers):
        idx_begin = ans[0]
        idx_end = ans[1]
        question = "What is the " + types[i] + "?"
        qa = question + "\t" + str(idx_begin) + " " + str(idx_end)
        ques_ans_list.append(qa)
    return ques_ans_list

# %%
from nltk.tokenize import sent_tokenize
import os

if 0:
    def find_entity_index(contract, entity):
            b = contract.find(entity)
            e = b + len(entity)
            idx = (b, e)
            if b == -1:
                return(-1, -1)
            return idx

        
def find_entity_index(sentence, entity):
    sentence_words = nlp.tokenizer(unicode(sentence))
    entity_words = nlp.tokenizer(unicode(entity))
    q = 0
    len_entity = len(entity_words)
    res = (-1, -1)
    while q < len(sentence_words) - len_entity:
        #if entity_words == sentence_words[q:q+len_entity]:
        if 0 :
            print
            print entity_words
            print sentence_words[q:q+len_entity]
            print check_euqal_tokens(entity_words, sentence_words[q:q+len_entity])
            print
        if check_euqal_tokens(entity_words, sentence_words[q:q+len_entity]):
            res = (q, q+len_entity)
            break
        q += 1
        
    print sentence_words
    print entity_words
    print res
    print 
    return res
    
def check_euqal_tokens(t1, t2):
    if len(t1) != len(t2):
        return False
    if not t1 and not t2:
        return True
    q = 0
    while q < len(t1):
        if str(t1[q]) != str(t2[q]):
            return False
        q += 1
    return True
    
    
    

    
    print sentence
    print entity
    print (start, end)
    return (start , end)

def generate_contract_qa(file_path, N_contracts):
    # file_path = "contracts_qa.txt"
    if os.path.isfile(file_path):
        os.remove(file_path)
    f = open(file_path, "a")

    # N_contracts = 10
    for i in range(N_contracts):
        r_contractor = random.randint(0, N_company-1)
        r_contractee = random.randint(0, N_company-1)
        while r_contractor == r_contractee:
            r_contractee = random.randint(0, N_company-1)
            
        contractor_name = company_names[r_contractor]
        contractor_addr = ", ".join([company_streets[r_contractor], company_cities[r_contractor], \
                                   company_states[r_contractor], company_zips[r_contractor]])
        contractee_name = company_names[r_contractee]
        contractee_addr = ", ".join([company_streets[r_contractee], company_cities[r_contractee], \
                                   company_states[r_contractee], company_zips[r_contractee]])
        effective_date = random_day_str()
        r_template = random.randint(0, N_template-1)
        contract = contract_templates[r_template]
        
        contract = contract.replace("CONTRACTOR_NAME", contractor_name)
              
        contractor_name_idx = find_entity_index(contract, contractor_name)
        #print contractor_name_idx
        
        contract = contract.replace("CONTRACTEE_NAME", contractee_name)
        contractee_name_idx = find_entity_index(contract, contractee_name)
        #print contractee_name_idx
        
        
        contract = contract.replace("CONTRACTOR_ADDR", contractor_addr)
        contractor_addr_idx = find_entity_index(contract,  contractor_addr)
        #print contractor_addr_idx
        
        contract = contract.replace("CONTRACTEE_ADDR", contractee_addr)
        contractee_addr_idx = find_entity_index(contract,  contractee_addr)
        #print contractee_addr_idx
        
        contract = contract.replace("EFFECTIVE_DATE", effective_date)
        effective_date_idx = find_entity_index(contract,   effective_date)
        #print effective_date_idx
        
        contract_sents = sent_tokenize(contract)
  

        ques_ans_list = qa_gen(contractor_name_idx, contractee_name_idx, contractor_addr_idx, contractee_addr_idx, effective_date_idx)

        for i, sent in enumerate(contract_sents):
            content = str(i+1) + " " + sent + "\n"
            f.write(content)
        for k, sent in enumerate(ques_ans_list):
            content = str(i+k+2) + " " + sent  + "\n"
            f.write(content)


    f.close()

    
    
generate_contract_qa("data/contract_data/contracts_train.txt", 10)
generate_contract_qa("data/contract_data/contracts_test.txt", 10)
# Out:
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between CONTRACTEE_NAME hereinafter called "Company" and Securian Financial Group, CONTRACTOR_ADDR, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# Securian Financial Group
# (16, 19)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between Sherwin-Williams hereinafter called "Company" and Securian Financial Group, CONTRACTOR_ADDR, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# Sherwin-Williams
# (9, 12)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between Sherwin-Williams hereinafter called "Company" and Securian Financial Group, 400 Robert St. N., Saint Paul, MN, 55101, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# 400 Robert St. N., Saint Paul, MN, 55101
# (22, 33)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between Sherwin-Williams hereinafter called "Company" and Securian Financial Group, 400 Robert St. N., Saint Paul, MN, 55101, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# 101 Prospect Ave. N.W., Cleveland, OH, 44115
# (-1, -1)
#
# THIS AGREEMENT made effective this 06/21/15 by and between Sherwin-Williams hereinafter called "Company" and Securian Financial Group, 400 Robert St. N., Saint Paul, MN, 55101, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# 06/21/15
# (5, 6)
#
# This contract is entered into on this EFFECTIVE_DATE, by and between Markel, a municipal corporation of the State of California and The CONTRACTEE_NAME, CONTRACTEE_ADDR. This contract consists of the following documents:
# Markel
# (12, 13)
#
# This contract is entered into on this EFFECTIVE_DATE, by and between Markel, a municipal corporation of the State of California and The Hewitt Associates, CONTRACTEE_ADDR. This contract consists of the following documents:
# Hewitt Associates
# (24, 26)
#
# This contract is entered into on this EFFECTIVE_DATE, by and between Markel, a municipal corporation of the State of California and The Hewitt Associates, CONTRACTEE_ADDR. This contract consists of the following documents:
# 4521 Highwoods Pkwy., Glen Allen, VA, 23060
# (-1, -1)
#
# This contract is entered into on this EFFECTIVE_DATE, by and between Markel, a municipal corporation of the State of California and The Hewitt Associates, 100 Half Day Rd., Prairie View, IL, 60069. This contract consists of the following documents:
# 100 Half Day Rd., Prairie View, IL, 60069
# (27, 39)
#
# This contract is entered into on this November 13, 1955, by and between Markel, a municipal corporation of the State of California and The Hewitt Associates, 100 Half Day Rd., Prairie View, IL, 60069. This contract consists of the following documents:
# November 13, 1955
# (7, 11)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Plum Creek Timber ( Contractor ), CONTRACTOR_ADDR, and CONTRACTEE_NAME ( Operator ), CONTRACTEE_ADDR  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# Plum Creek Timber
# (18, 21)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Plum Creek Timber ( Contractor ), CONTRACTOR_ADDR, and United Parcel Service ( Operator ), CONTRACTEE_ADDR  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# United Parcel Service
# (28, 31)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Plum Creek Timber ( Contractor ), 999 Third Ave., Seattle, WA, 98104, and United Parcel Service ( Operator ), CONTRACTEE_ADDR  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# 999 Third Ave., Seattle, WA, 98104
# (25, 35)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Plum Creek Timber ( Contractor ), 999 Third Ave., Seattle, WA, 98104, and United Parcel Service ( Operator ), 55 Glenlake Pkwy. N.E., Sandy Springs, GA, 30328  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# 55 Glenlake Pkwy. N.E., Sandy Springs, GA, 30328
# (44, 56)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into 2008-03-31 ( Effective Date ) between Plum Creek Timber ( Contractor ), 999 Third Ave., Seattle, WA, 98104, and United Parcel Service ( Operator ), 55 Glenlake Pkwy. N.E., Sandy Springs, GA, 30328  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# 2008-03-31
# (12, 17)
#
# This contract serves as the Master Services Agreement (Agreement) under which orders may be issued for professional services to be performed by the division of Country Insurance & Fin. Svcs. listed in the Addresses and Points of Contact section of this Agreement. This Agreement  is entered into by Country Insurance & Fin. Svcs., CONTRACTOR_ADDR, and CONTRACTEE_NAME, CONTRACTEE_ADDR,  and is effective as of date signed. This agreement is effective from EFFECTIVE_DATE. For the purposes of this agreement, Country Insurance & Fin. Svcs. and the Customer may be referred to as such or as the Parties to this agreement.
# Country Insurance & Fin. Svcs.
# (27, 34)
#
# This contract serves as the Master Services Agreement (Agreement) under which orders may be issued for professional services to be performed by the division of Country Insurance & Fin. Svcs. listed in the Addresses and Points of Contact section of this Agreement. This Agreement  is entered into by Country Insurance & Fin. Svcs., CONTRACTOR_ADDR, and Rock-Tenn, CONTRACTEE_ADDR,  and is effective as of date signed. This agreement is effective from EFFECTIVE_DATE. For the purposes of this agreement, Country Insurance & Fin. Svcs. and the Customer may be referred to as such or as the Parties to this agreement.
# Rock-Tenn
# (65, 68)
#
# This contract serves as the Master Services Agreement (Agreement) under which orders may be issued for professional services to be performed by the division of Country Insurance & Fin. Svcs. listed in the Addresses and Points of Contact section of this Agreement. This Agreement  is entered into by Country Insurance & Fin. Svcs., 1701 N. Towanda Ave., Bloomington, IL, 61702, and Rock-Tenn, CONTRACTEE_ADDR,  and is effective as of date signed. This agreement is effective from EFFECTIVE_DATE. For the purposes of this agreement, Country Insurance & Fin. Svcs. and the Customer may be referred to as such or as the Parties to this agreement.
# 1701 N. Towanda Ave., Bloomington, IL, 61702
# (62, 73)
#
# This contract serves as the Master Services Agreement (Agreement) under which orders may be issued for professional services to be performed by the division of Country Insurance & Fin. Svcs. listed in the Addresses and Points of Contact section of this Agreement. This Agreement  is entered into by Country Insurance & Fin. Svcs., 1701 N. Towanda Ave., Bloomington, IL, 61702, and Rock-Tenn, 504 Thrasher St., Norcross, GA, 30071,  and is effective as of date signed. This agreement is effective from EFFECTIVE_DATE. For the purposes of this agreement, Country Insurance & Fin. Svcs. and the Customer may be referred to as such or as the Parties to this agreement.
# 504 Thrasher St., Norcross, GA, 30071
# (79, 88)
#
# This contract serves as the Master Services Agreement (Agreement) under which orders may be issued for professional services to be performed by the division of Country Insurance & Fin. Svcs. listed in the Addresses and Points of Contact section of this Agreement. This Agreement  is entered into by Country Insurance & Fin. Svcs., 1701 N. Towanda Ave., Bloomington, IL, 61702, and Rock-Tenn, 504 Thrasher St., Norcross, GA, 30071,  and is effective as of date signed. This agreement is effective from December 13, 97. For the purposes of this agreement, Country Insurance & Fin. Svcs. and the Customer may be referred to as such or as the Parties to this agreement.
# December 13, 97
# (103, 107)
#
# This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between The PerkinElmer, a Virginia corporation (Consultant), and the CONTRACTEE_NAME, a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# PerkinElmer
# (20, 21)
#
# This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between The PerkinElmer, a Virginia corporation (Consultant), and the Country Insurance & Fin. Svcs., a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# Country Insurance & Fin. Svcs.
# (31, 38)
#
# This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between The PerkinElmer, a Virginia corporation (Consultant), and the Country Insurance & Fin. Svcs., a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# 940 Winter St., Waltham, MA, 2451
# (-1, -1)
#
# This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between The PerkinElmer, a Virginia corporation (Consultant), and the Country Insurance & Fin. Svcs., a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# 1701 N. Towanda Ave., Bloomington, IL, 61702
# (-1, -1)
#
# This Contract is entered into as of the day of November 03, 65: (Effective Date) by and between The PerkinElmer, a Virginia corporation (Consultant), and the Country Insurance & Fin. Svcs., a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# November 03, 65
# (10, 14)
#
# THIS AGREEMENT (Agreement), which comprises the full and complete agreement of the Parties hereto and supersedes all previous agreements between the Parties relating to the subject matter hereof, is entered into the EFFECTIVE_DATE, by and between CONTRACTEE_NAME, CONTRACTEE_ADDR, for itself and its wholly owned subsidiaries (Company), and Oracle, CONTRACTOR_ADDR, (Contractor). Company and Contractor are sometimes referred to hereinafter individually as a Party or collectively as the Parties.
# Oracle
# (57, 58)
#
# THIS AGREEMENT (Agreement), which comprises the full and complete agreement of the Parties hereto and supersedes all previous agreements between the Parties relating to the subject matter hereof, is entered into the EFFECTIVE_DATE, by and between Wisconsin Energy, CONTRACTEE_ADDR, for itself and its wholly owned subsidiaries (Company), and Oracle, CONTRACTOR_ADDR, (Contractor). Company and Contractor are sometimes referred to hereinafter individually as a Party or collectively as the Parties.
# Wisconsin Energy
# (41, 43)
#
# THIS AGREEMENT (Agreement), which comprises the full and complete agreement of the Parties hereto and supersedes all previous agreements between the Parties relating to the subject matter hereof, is entered into the EFFECTIVE_DATE, by and between Wisconsin Energy, CONTRACTEE_ADDR, for itself and its wholly owned subsidiaries (Company), and Oracle, 500 Oracle Pkwy., Redwood City, CA, 94065, (Contractor). Company and Contractor are sometimes referred to hereinafter individually as a Party or collectively as the Parties.
# 500 Oracle Pkwy., Redwood City, CA, 94065
# (60, 71)
#
# THIS AGREEMENT (Agreement), which comprises the full and complete agreement of the Parties hereto and supersedes all previous agreements between the Parties relating to the subject matter hereof, is entered into the EFFECTIVE_DATE, by and between Wisconsin Energy, 231 W. Michigan St., Milwaukee, WI, 53203, for itself and its wholly owned subsidiaries (Company), and Oracle, 500 Oracle Pkwy., Redwood City, CA, 94065, (Contractor). Company and Contractor are sometimes referred to hereinafter individually as a Party or collectively as the Parties.
# 231 W. Michigan St., Milwaukee, WI, 53203
# (44, 54)
#
# THIS AGREEMENT (Agreement), which comprises the full and complete agreement of the Parties hereto and supersedes all previous agreements between the Parties relating to the subject matter hereof, is entered into the 11 21, 09, by and between Wisconsin Energy, 231 W. Michigan St., Milwaukee, WI, 53203, for itself and its wholly owned subsidiaries (Company), and Oracle, 500 Oracle Pkwy., Redwood City, CA, 94065, (Contractor). Company and Contractor are sometimes referred to hereinafter individually as a Party or collectively as the Parties.
# 11 21, 09
# (36, 40)
#
# THIS AGREEMENT (Agreement), which comprises the full and complete agreement of the Parties hereto and supersedes all previous agreements between the Parties relating to the subject matter hereof, is entered into the EFFECTIVE_DATE, by and between CONTRACTEE_NAME, CONTRACTEE_ADDR, for itself and its wholly owned subsidiaries (Company), and Electronic Data Systems, CONTRACTOR_ADDR, (Contractor). Company and Contractor are sometimes referred to hereinafter individually as a Party or collectively as the Parties.
# Electronic Data Systems
# (57, 60)
#
# THIS AGREEMENT (Agreement), which comprises the full and complete agreement of the Parties hereto and supersedes all previous agreements between the Parties relating to the subject matter hereof, is entered into the EFFECTIVE_DATE, by and between Foot Locker, CONTRACTEE_ADDR, for itself and its wholly owned subsidiaries (Company), and Electronic Data Systems, CONTRACTOR_ADDR, (Contractor). Company and Contractor are sometimes referred to hereinafter individually as a Party or collectively as the Parties.
# Foot Locker
# (41, 43)
#
# THIS AGREEMENT (Agreement), which comprises the full and complete agreement of the Parties hereto and supersedes all previous agreements between the Parties relating to the subject matter hereof, is entered into the EFFECTIVE_DATE, by and between Foot Locker, CONTRACTEE_ADDR, for itself and its wholly owned subsidiaries (Company), and Electronic Data Systems, 5400 Legacy Dr., Plano, TX, 75024, (Contractor). Company and Contractor are sometimes referred to hereinafter individually as a Party or collectively as the Parties.
# 5400 Legacy Dr., Plano, TX, 75024
# (62, 71)
#
# THIS AGREEMENT (Agreement), which comprises the full and complete agreement of the Parties hereto and supersedes all previous agreements between the Parties relating to the subject matter hereof, is entered into the EFFECTIVE_DATE, by and between Foot Locker, 112 W. 34th St., New York, NY, 10120, for itself and its wholly owned subsidiaries (Company), and Electronic Data Systems, 5400 Legacy Dr., Plano, TX, 75024, (Contractor). Company and Contractor are sometimes referred to hereinafter individually as a Party or collectively as the Parties.
# 112 W. 34th St., New York, NY, 10120
# (44, 55)
#
# THIS AGREEMENT (Agreement), which comprises the full and complete agreement of the Parties hereto and supersedes all previous agreements between the Parties relating to the subject matter hereof, is entered into the 1974-05-26, by and between Foot Locker, 112 W. 34th St., New York, NY, 10120, for itself and its wholly owned subsidiaries (Company), and Electronic Data Systems, 5400 Legacy Dr., Plano, TX, 75024, (Contractor). Company and Contractor are sometimes referred to hereinafter individually as a Party or collectively as the Parties.
# 1974-05-26
# (36, 41)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Zimmer Holdings ( Contractor ), CONTRACTOR_ADDR, and CONTRACTEE_NAME ( Operator ).  Contractor and Operator are also referred to as  party  and collectively as the  parties .  Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# Zimmer Holdings
# (18, 20)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Zimmer Holdings ( Contractor ), CONTRACTOR_ADDR, and Tesoro ( Operator ).  Contractor and Operator are also referred to as  party  and collectively as the  parties .  Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# Tesoro
# (27, 28)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Zimmer Holdings ( Contractor ), 345 E. Main St., Warsaw, IN, 46580, and Tesoro ( Operator ).  Contractor and Operator are also referred to as  party  and collectively as the  parties .  Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# 345 E. Main St., Warsaw, IN, 46580
# (24, 34)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Zimmer Holdings ( Contractor ), 345 E. Main St., Warsaw, IN, 46580, and Tesoro ( Operator ).  Contractor and Operator are also referred to as  party  and collectively as the  parties .  Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# 300 Concord Plaza Dr., San Antonio, TX, 78216
# (-1, -1)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into 12 03, 64 ( Effective Date ) between Zimmer Holdings ( Contractor ), 345 E. Main St., Warsaw, IN, 46580, and Tesoro ( Operator ).  Contractor and Operator are also referred to as  party  and collectively as the  parties .  Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# 12 03, 64
# (12, 16)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Calumet Specialty Products, CONTRACTOR_ADDR, ( Contractor ) and CONTRACTEE_NAME ( Operator ).  Contractor and Operator are also referred to as  party  and collectively as the  parties .  Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged.
# Calumet Specialty Products
# (18, 21)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Calumet Specialty Products, CONTRACTOR_ADDR, ( Contractor ) and Commerce Bancorp ( Operator ).  Contractor and Operator are also referred to as  party  and collectively as the  parties .  Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged.
# Commerce Bancorp
# (28, 30)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Calumet Specialty Products, 2780 Waterford Pkwy. E. Dr., Eagle Creek, IN, 46214, ( Contractor ) and Commerce Bancorp ( Operator ).  Contractor and Operator are also referred to as  party  and collectively as the  parties .  Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged.
# 2780 Waterford Pkwy. E. Dr., Eagle Creek, IN, 46214
# (22, 35)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Calumet Specialty Products, 2780 Waterford Pkwy. E. Dr., Eagle Creek, IN, 46214, ( Contractor ) and Commerce Bancorp ( Operator ).  Contractor and Operator are also referred to as  party  and collectively as the  parties .  Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged.
# 1701 Rt. 70 E., Cherry Hill, NJ, 8034
# (-1, -1)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into November 07, 1952 ( Effective Date ) between Calumet Specialty Products, 2780 Waterford Pkwy. E. Dr., Eagle Creek, IN, 46214, ( Contractor ) and Commerce Bancorp ( Operator ).  Contractor and Operator are also referred to as  party  and collectively as the  parties .  Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged.
# November 07, 1952
# (12, 16)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between CONTRACTEE_NAME hereinafter called "Company" and Brown Shoe, CONTRACTOR_ADDR, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# Brown Shoe
# (16, 18)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between SkyWest hereinafter called "Company" and Brown Shoe, CONTRACTOR_ADDR, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# SkyWest
# (9, 10)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between SkyWest hereinafter called "Company" and Brown Shoe, 8300 Maryland Ave., Clayton, MO, 63105, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# 8300 Maryland Ave., Clayton, MO, 63105
# (19, 29)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between SkyWest hereinafter called "Company" and Brown Shoe, 8300 Maryland Ave., Clayton, MO, 63105, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# 444 S. River Rd., St. George, UT, 84790
# (-1, -1)
#
# THIS AGREEMENT made effective this September 17, 1982 by and between SkyWest hereinafter called "Company" and Brown Shoe, 8300 Maryland Ave., Clayton, MO, 63105, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# September 17, 1982
# (5, 9)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between CONTRACTEE_NAME hereinafter called "Company" and Century Aluminum, CONTRACTOR_ADDR, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# Century Aluminum
# (16, 18)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between Allegheny Energymnitows@alleghenyenergy.com hereinafter called "Company" and Century Aluminum, CONTRACTOR_ADDR, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# Allegheny Energymnitows@alleghenyenergy.com
# (9, 11)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between Allegheny Energymnitows@alleghenyenergy.com hereinafter called "Company" and Century Aluminum, 2511 Garden Rd., Del Rey Oaks, CA, 93940, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# 2511 Garden Rd., Del Rey Oaks, CA, 93940
# (20, 32)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between Allegheny Energymnitows@alleghenyenergy.com hereinafter called "Company" and Century Aluminum, 2511 Garden Rd., Del Rey Oaks, CA, 93940, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# 800 Cabin Hill Dr., Greensburg, PA, 15601
# (-1, -1)
#
# THIS AGREEMENT made effective this 03 26, 1995 by and between Allegheny Energymnitows@alleghenyenergy.com hereinafter called "Company" and Century Aluminum, 2511 Garden Rd., Del Rey Oaks, CA, 93940, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# 03 26, 1995
# (5, 9)
#
# This Services Agreement (the Agreement) sets forth terms under that The Hertz Global Holdings (Company), CONTRACTOR_ADDR shall provide services to the CONTRACTEE_NAME (the Client). This Agreement is effective as of EFFECTIVE_DATE (Effective Date).
# Hertz Global Holdings
# (13, 16)
#
# This Services Agreement (the Agreement) sets forth terms under that The Hertz Global Holdings (Company), CONTRACTOR_ADDR shall provide services to the Perot Systems (the Client). This Agreement is effective as of EFFECTIVE_DATE (Effective Date).
# Perot Systems
# (26, 28)
#
# This Services Agreement (the Agreement) sets forth terms under that The Hertz Global Holdings (Company), 225 Brae Blvd., Park Ridge, NJ, 7656 shall provide services to the Perot Systems (the Client). This Agreement is effective as of EFFECTIVE_DATE (Effective Date).
# 225 Brae Blvd., Park Ridge, NJ, 7656
# (20, 31)
#
# This Services Agreement (the Agreement) sets forth terms under that The Hertz Global Holdings (Company), 225 Brae Blvd., Park Ridge, NJ, 7656 shall provide services to the Perot Systems (the Client). This Agreement is effective as of EFFECTIVE_DATE (Effective Date).
# 2300 W. Plano Pkwy., Plano, TX, 75075
# (-1, -1)
#
# This Services Agreement (the Agreement) sets forth terms under that The Hertz Global Holdings (Company), 225 Brae Blvd., Park Ridge, NJ, 7656 shall provide services to the Perot Systems (the Client). This Agreement is effective as of April 03, 1954 (Effective Date).
# April 03, 1954
# (49, 53)
#
# This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between The Newfield Exploration, a Virginia corporation (Consultant), and the CONTRACTEE_NAME, a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# Newfield Exploration
# (20, 22)
#
# This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between The Newfield Exploration, a Virginia corporation (Consultant), and the Electronic Data Systems, a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# Electronic Data Systems
# (32, 35)
#
# This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between The Newfield Exploration, a Virginia corporation (Consultant), and the Electronic Data Systems, a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# 363 N. Sam Houston Pkwy. E., Houston, TX, 77060
# (-1, -1)
#
# This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between The Newfield Exploration, a Virginia corporation (Consultant), and the Electronic Data Systems, a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# 5400 Legacy Dr., Plano, TX, 75024
# (-1, -1)
#
# This Contract is entered into as of the day of December 24, 2001: (Effective Date) by and between The Newfield Exploration, a Virginia corporation (Consultant), and the Electronic Data Systems, a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# December 24, 2001
# (10, 14)
#
# This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between The Bear Stearns, a Virginia corporation (Consultant), and the CONTRACTEE_NAME, a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# Bear Stearns
# (20, 22)
#
# This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between The Bear Stearns, a Virginia corporation (Consultant), and the Metal Management, a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# Metal Management
# (32, 34)
#
# This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between The Bear Stearns, a Virginia corporation (Consultant), and the Metal Management, a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# 383 Madison Ave., New York, NY, 10179
# (-1, -1)
#
# This Contract is entered into as of the day of EFFECTIVE_DATE: (Effective Date) by and between The Bear Stearns, a Virginia corporation (Consultant), and the Metal Management, a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# 325 N. LaSalle St., Chicago, IL, 60610
# (-1, -1)
#
# This Contract is entered into as of the day of 1966-03-07: (Effective Date) by and between The Bear Stearns, a Virginia corporation (Consultant), and the Metal Management, a municipal corporation and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Office of Emergency Management and Communications (City), at Chicago, Illinois.
# 1966-03-07
# (10, 15)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Atmel ( Contractor ), CONTRACTOR_ADDR, and CONTRACTEE_NAME ( Operator ), CONTRACTEE_ADDR  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# Atmel
# (18, 19)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Atmel ( Contractor ), CONTRACTOR_ADDR, and Marathon Oil ( Operator ), CONTRACTEE_ADDR  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# Marathon Oil
# (26, 28)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Atmel ( Contractor ), 2325 Orchard Pkwy., San Jose, CA, 95131, and Marathon Oil ( Operator ), CONTRACTEE_ADDR  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# 2325 Orchard Pkwy., San Jose, CA, 95131
# (23, 34)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Atmel ( Contractor ), 2325 Orchard Pkwy., San Jose, CA, 95131, and Marathon Oil ( Operator ), 5555 San Felipe Rd., Houston, TX, 77056  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# 5555 San Felipe Rd., Houston, TX, 77056
# (42, 53)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into 03 16, 1994 ( Effective Date ) between Atmel ( Contractor ), 2325 Orchard Pkwy., San Jose, CA, 95131, and Marathon Oil ( Operator ), 5555 San Felipe Rd., Houston, TX, 77056  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# 03 16, 1994
# (12, 16)
#
# This contract serves as the Master Services Agreement (Agreement) under which orders may be issued for professional services to be performed by the division of Ameriprise Financial listed in the Addresses and Points of Contact section of this Agreement. This Agreement  is entered into by Ameriprise Financial, CONTRACTOR_ADDR, and CONTRACTEE_NAME, CONTRACTEE_ADDR,  and is effective as of date signed. This agreement is effective from EFFECTIVE_DATE. For the purposes of this agreement, Ameriprise Financial and the Customer may be referred to as such or as the Parties to this agreement.
# Ameriprise Financial
# (27, 29)
#
# This contract serves as the Master Services Agreement (Agreement) under which orders may be issued for professional services to be performed by the division of Ameriprise Financial listed in the Addresses and Points of Contact section of this Agreement. This Agreement  is entered into by Ameriprise Financial, CONTRACTOR_ADDR, and United Services Automobile Assn., CONTRACTEE_ADDR,  and is effective as of date signed. This agreement is effective from EFFECTIVE_DATE. For the purposes of this agreement, Ameriprise Financial and the Customer may be referred to as such or as the Parties to this agreement.
# United Services Automobile Assn.
# (55, 60)
#
# This contract serves as the Master Services Agreement (Agreement) under which orders may be issued for professional services to be performed by the division of Ameriprise Financial listed in the Addresses and Points of Contact section of this Agreement. This Agreement  is entered into by Ameriprise Financial, 55 Ameriprise Financial Center, Minneapolis, MN, 55474, and United Services Automobile Assn., CONTRACTEE_ADDR,  and is effective as of date signed. This agreement is effective from EFFECTIVE_DATE. For the purposes of this agreement, Ameriprise Financial and the Customer may be referred to as such or as the Parties to this agreement.
# 55 Ameriprise Financial Center, Minneapolis, MN, 55474
# (52, 62)
#
# This contract serves as the Master Services Agreement (Agreement) under which orders may be issued for professional services to be performed by the division of Ameriprise Financial listed in the Addresses and Points of Contact section of this Agreement. This Agreement  is entered into by Ameriprise Financial, 55 Ameriprise Financial Center, Minneapolis, MN, 55474, and United Services Automobile Assn., 9800 Fredericksburg Rd, San Antonio, TX, 78288,  and is effective as of date signed. This agreement is effective from EFFECTIVE_DATE. For the purposes of this agreement, Ameriprise Financial and the Customer may be referred to as such or as the Parties to this agreement.
# 9800 Fredericksburg Rd, San Antonio, TX, 78288
# (70, 80)
#
# This contract serves as the Master Services Agreement (Agreement) under which orders may be issued for professional services to be performed by the division of Ameriprise Financial listed in the Addresses and Points of Contact section of this Agreement. This Agreement  is entered into by Ameriprise Financial, 55 Ameriprise Financial Center, Minneapolis, MN, 55474, and United Services Automobile Assn., 9800 Fredericksburg Rd, San Antonio, TX, 78288,  and is effective as of date signed. This agreement is effective from Dec 11, 1963. For the purposes of this agreement, Ameriprise Financial and the Customer may be referred to as such or as the Parties to this agreement.
# Dec 11, 1963
# (95, 99)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between CONTRACTEE_NAME hereinafter called "Company" and M&T Bank Corp., CONTRACTOR_ADDR, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# M&T Bank Corp.
# (16, 19)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between Juniper Networks hereinafter called "Company" and M&T Bank Corp., CONTRACTOR_ADDR, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# Juniper Networks
# (9, 11)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between Juniper Networks hereinafter called "Company" and M&T Bank Corp., 1 M&amp;T Plaza, Buffalo, NY, 14203, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# 1 M&amp;T Plaza, Buffalo, NY, 14203
# (21, 30)
#
# THIS AGREEMENT made effective this EFFECTIVE_DATE by and between Juniper Networks hereinafter called "Company" and M&T Bank Corp., 1 M&amp;T Plaza, Buffalo, NY, 14203, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# 1194 N. Mathilda Ave., Sunnyvale, CA, 94089
# (-1, -1)
#
# THIS AGREEMENT made effective this 03 21, 86 by and between Juniper Networks hereinafter called "Company" and M&T Bank Corp., 1 M&amp;T Plaza, Buffalo, NY, 14203, hereinafter called "Contractor," whereby, in consideration of the covenants and provisions hereinafter provided, this Agreement shall control and govern all work performed or to be performed by Contractor for Company under verbal or written work orders, purchase orders, delivery tickets, voices or other verbal or written agreements between the Parties, relating to work to be done by Contractor for Company, and upersede any such previous agreements from date hereof until specifically cancelled in writing by either Party, anything to the co in any such agreement notwithstanding. This Agreement does not obligate Company to order work from Contractor, nor obligate Contractor to accept orders for work
# 03 21, 86
# (5, 9)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Commerce Group ( Contractor ), CONTRACTOR_ADDR, and CONTRACTEE_NAME ( Operator ), CONTRACTEE_ADDR  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# Commerce Group
# (18, 20)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Commerce Group ( Contractor ), CONTRACTOR_ADDR, and PNM Resources ( Operator ), CONTRACTEE_ADDR  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# PNM Resources
# (27, 29)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Commerce Group ( Contractor ), 211 Main St., Dudley Hill, MA, 1570, and PNM Resources ( Operator ), CONTRACTEE_ADDR  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# 211 Main St., Dudley Hill, MA, 1570
# (24, 34)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into EFFECTIVE_DATE ( Effective Date ) between Commerce Group ( Contractor ), 211 Main St., Dudley Hill, MA, 1570, and PNM Resources ( Operator ), Alvarado Square, Albuquerque, NM, 87158  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# Alvarado Square, Albuquerque, NM, 87158
# (42, 50)
#
# THIS MASTER SERVICE AGREEMENT ( Agreement ) is made and entered into June 05, 2016 ( Effective Date ) between Commerce Group ( Contractor ), 211 Main St., Dudley Hill, MA, 1570, and PNM Resources ( Operator ), Alvarado Square, Albuquerque, NM, 87158  Contractor and Operator are also referred to as  party  and collectively as the  parties . Subject to and in consideration of the mutual promises, conditions, and agreements contained herein, the receipt and sufficiency of which are hereby acknowledged, the parties agree as follows: Kunling LLC has owed Darshi Inc. 20000 dollars on August 1st, 2017.
# June 05, 2016
# (12, 16)
#
# This contract is entered into on this EFFECTIVE_DATE, by and between Unum Group, a municipal corporation of the State of California and The CONTRACTEE_NAME, CONTRACTEE_ADDR. This contract consists of the following documents:
# Unum Group
# (12, 14)
#
# This contract is entered into on this EFFECTIVE_DATE, by and between Unum Group, a municipal corporation of the State of California and The United States Steel, CONTRACTEE_ADDR. This contract consists of the following documents:
# United States Steel
# (25, 28)
#
# This contract is entered into on this EFFECTIVE_DATE, by and between Unum Group, a municipal corporation of the State of California and The United States Steel, CONTRACTEE_ADDR. This contract consists of the following documents:
# 1 Fountain Square, Chattanooga, TN, 37402
# (-1, -1)
#
# This contract is entered into on this EFFECTIVE_DATE, by and between Unum Group, a municipal corporation of the State of California and The United States Steel, 600 Grant St., Uptown, PA, 15219. This contract consists of the following documents:
# 600 Grant St., Uptown, PA, 15219
# (29, 38)
#
# This contract is entered into on this Apr 07, 2017, by and between Unum Group, a municipal corporation of the State of California and The United States Steel, 600 Grant St., Uptown, PA, 15219. This contract consists of the following documents:
# Apr 07, 2017
# (7, 11)
#
# This Master Task Order Contract is entered into as of the EFFECTIVE_DATE (Effective Date) by and between Weyerhaeuser, Inc., (Consultant), CONTRACTOR_ADDR, and the CONTRACTEE_NAME, CONTRACTEE_ADDRand home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Chicago Department of Public Health (City), at Chicago, Illinois.
# Weyerhaeuser
# (19, 20)
#
# This Master Task Order Contract is entered into as of the EFFECTIVE_DATE (Effective Date) by and between Weyerhaeuser, Inc., (Consultant), CONTRACTOR_ADDR, and the Wyndham Worldwide, CONTRACTEE_ADDRand home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Chicago Department of Public Health (City), at Chicago, Illinois.
# Wyndham Worldwide
# (31, 33)
#
# This Master Task Order Contract is entered into as of the EFFECTIVE_DATE (Effective Date) by and between Weyerhaeuser, Inc., (Consultant), 33663 Weyerhaeuser Way S., Federal Way, WA, 98063, and the Wyndham Worldwide, CONTRACTEE_ADDRand home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Chicago Department of Public Health (City), at Chicago, Illinois.
# 33663 Weyerhaeuser Way S., Federal Way, WA, 98063
# (27, 38)
#
# This Master Task Order Contract is entered into as of the EFFECTIVE_DATE (Effective Date) by and between Weyerhaeuser, Inc., (Consultant), 33663 Weyerhaeuser Way S., Federal Way, WA, 98063, and the Wyndham Worldwide, 7 Sylvan Way, Parsippany, NJ, 7054and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Chicago Department of Public Health (City), at Chicago, Illinois.
# 7 Sylvan Way, Parsippany, NJ, 7054
# (-1, -1)
#
# This Master Task Order Contract is entered into as of the 10 05, 09 (Effective Date) by and between Weyerhaeuser, Inc., (Consultant), 33663 Weyerhaeuser Way S., Federal Way, WA, 98063, and the Wyndham Worldwide, 7 Sylvan Way, Parsippany, NJ, 7054and home rule unit of local government existing under the Constitution of the State of Illinois, acting through its Chicago Department of Public Health (City), at Chicago, Illinois.
# 10 05, 09
# (11, 15)

# %%
a = [1, 2]
b = [1, 'a']

# %%
print a == b
# Out:
# False

# %%
EXAMPLE_TEXT = "Hello Mr. Smith, how are you doing today? The weather is great, and Python is awesome. The sky is pinkish-blue. You shouldn't eat cardboard."

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
print(word_tokenize(EXAMPLE_TEXT))
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'Python', 'is', 'awesome.', 'The', 'sky', 'is', 'pinkish-blue.', 'You', 'should', "n't", 'eat', 'cardboard', '.']

# %%
# Out:
# Hello

# %%
for d in doc:
    print d
# Out:
# Hello
# Mr.
# Smith
# ,
# how
# are
# you
# doing
# today
# ?
# The
# weather
# is
# great
# ,
# and
# Python
# is
# awesome
# .
# The
# sky
# is
# pinkish
# -
# blue
# .
# You
# should
# n't
# eat
# cardboard
# .

# %%
print len(doc)
# Out:
# 33

# %%
doc2 = nlp.tokenizer(unicode("I love you"))
print str(doc2[0]) == str(doc2[0])
# Out:
# True
